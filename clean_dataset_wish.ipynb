# %% [markdown]
# # frist csv

# %% [markdown]
# ## Data loading and Exploretion

# %%
# !kaggle datasets download -d jmmvutu/summer-products-and-sales-in-ecommerce-wish
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jmmvutu/summer-products-and-sales-in-ecommerce-wish
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
#   0% 0.00/406k [00:00<?, ?B/s]
# 100% 406k/406k [00:00<00:00, 48.1MB/s]

# %%
# !unzip /content/summer-products-and-sales-in-ecommerce-wish.zip
# Out:
# Archive:  /content/summer-products-and-sales-in-ecommerce-wish.zip
#   inflating: computed_insight_success_of_active_sellers.csv
#   inflating: summer-products-with-rating-and-performance_2020-08.csv
#   inflating: unique-categories.csv
#   inflating: unique-categories.sorted-by-count.csv

# %%
import pandas as pd

# %%
def try_encodings(file_path):
    encodings = ['utf-8', 'latin1', 'iso-8859-1', 'windows-1252', 'ascii', 'utf-16', 'utf-32']

    for encoding in encodings:
        try:
            df = pd.read_csv(file_path, encoding=encoding)
            print(f"Success encoding: {encoding}")
            return df
        except Exception as e:
            print(f"Failed encoding: {encoding} - Error: {e}")

    print("None of the encodings worked correctly.")
    return None

file_path = '/content/computed_insight_success_of_active_sellers.csv'

df = try_encodings(file_path)
# Out:
# Success encoding: utf-8

# %%
df.head()
# Out:
#                  merchantid  listedproducts  totalunitssold  \
# 0  5357bcf2bb72c5504882e889               2          120000
# 1  5708773c3c02161b3f8c7900               5          107100
# 2  5417aada4ad3ab27e954b76c               2          100007
# 3  570f3a713a698c14278bb51e               1          100000
# 4  53082ea15aefb07dfe1f2a4f               1          100000
#
#    meanunitssoldperproduct  rating  merchantratingscount  meanproductprices  \
# 0                  60000.0   4.219              320031.0               9.00
# 1                  21420.0   3.934              139223.0               7.76
# 2                  50004.0   4.053              108048.0               8.00
# 3                 100000.0   3.889               19248.0               5.67
# 4                 100000.0   4.036              366898.0               5.00
#
#    meanretailprices  averagediscount  meandiscount  meanproductratingscount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   merchantid               958 non-null    object
#  1   listedproducts           958 non-null    int64
#  2   totalunitssold           958 non-null    int64
#  3   meanunitssoldperproduct  958 non-null    float64
#  4   rating                   958 non-null    float64
#  5   merchantratingscount     958 non-null    float64
#  6   meanproductprices        958 non-null    float64
#  7   meanretailprices         958 non-null    float64
#  8   averagediscount          958 non-null    float64
#  9   meandiscount             958 non-null    float64
#  10  meanproductratingscount  958 non-null    float64
#  11  totalurgencycount        391 non-null    float64
#  12  urgencytextrate          391 non-null    float64
# dtypes: float64(10), int64(2), object(1)
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# merchantid                   0
# listedproducts               0
# totalunitssold               0
# meanunitssoldperproduct      0
# rating                       0
# merchantratingscount         0
# meanproductprices            0
# meanretailprices             0
# averagediscount              0
# meandiscount                 0
# meanproductratingscount      0
# totalurgencycount          567
# urgencytextrate            567
# dtype: int64

# %%
df.shape
# Out:
# (958, 13)

# %%
df.describe()
# Out:
#        listedproducts  totalunitssold  meanunitssoldperproduct      rating  \
# count      958.000000      958.000000               958.000000  958.000000
# mean         1.641962     7124.483299              4407.605428    4.043994
# std          1.246183    14363.521893              9167.077812    0.222137
# min          1.000000        1.000000                 1.000000    2.333000
# 25%          1.000000      100.000000               100.000000    3.931000
# 50%          1.000000     1000.000000              1000.000000    4.055500
# 75%          2.000000    10000.000000              5000.000000    4.190000
# max         15.000000   120000.000000            100000.000000    5.000000
#
#        merchantratingscount  meanproductprices  meanretailprices  \
# count          9.580000e+02         958.000000        958.000000
# mean           2.202045e+04           8.634906         24.802265
# std            8.473232e+04           3.987599         30.258719
# ...

# %% [markdown]
# ## data clean

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.041    6
# 3.965    5
# 3.968    5
# 4.228    5
# 4.007    5
#         ..
# 4.012    1
# 3.908    1
# 3.862    1
# 3.677    1
# 3.598    1
# Name: count, Length: 552, dtype: int64

# %%
subdf=df[df['totalurgencycount'].isnull()]
subdf
# Out:
#                    merchantid  listedproducts  totalunitssold  \
# 2    5417aada4ad3ab27e954b76c               2          100007
# 4    53082ea15aefb07dfe1f2a4f               1          100000
# 5    53f2beb39020ee03566d6e18               1          100000
# 14   53aa664438d3046ee44a5024               4           60100
# 16   5384613a796f680f9d78a127               3           60000
# ..                        ...             ...             ...
# 953  567bad8582c35f28103e5813               1               2
# 954  5b24edf0d1c360301099e9c6               1               2
# 955  5d417e7070327a2743021677               1               1
# 956  5add589edb5f1f32114d07df               1               1
# 957  5d4b8931933fb13f8a1fe232               1               1
#
#      meanunitssoldperproduct  rating  merchantratingscount  meanproductprices  \
# 2                    50004.0   4.053              108048.0               8.00
# ...

# %%
subdf.isnull().sum()
# Out:
# merchantid                   0
# listedproducts               0
# totalunitssold               0
# meanunitssoldperproduct      0
# rating                       0
# merchantratingscount         0
# meanproductprices            0
# meanretailprices             0
# averagediscount              0
# meandiscount                 0
# meanproductratingscount      0
# totalurgencycount          567
# urgencytextrate            567
# dtype: int64

# %%
df['totalurgencycount'].value_counts()
# Out:
# totalurgencycount
# 1.0    331
# 2.0     46
# 3.0      9
# 4.0      3
# 6.0      1
# 5.0      1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
df['totalurgencycount'].value_counts(dropna=False).sort_index().plot(kind='bar', color='skyblue')

plt.title('Distribution of Total Urgency Count', fontsize=14)
plt.xlabel('Total Urgency Count', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.show()

# %%
df.fillna({'totalurgencycount':0},inplace=True)

# %%
df.fillna({'urgencytextrate':0},inplace=True)

# %%
df.drop('averagediscount',axis=1,inplace=True)

# %%
df.to_csv('cleaned_computed_insight_success_of_active_sellers.csv', index=False)

# %% [markdown]
# # 2nd

# %% [markdown]
# ## loading data and explore

# %%
file_path = '/content/summer-products-with-rating-and-performance_2020-08.csv'

data2 = try_encodings(file_path)

data2.head()
# Out:
# Success encoding: utf-8
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4  Femmes Shorts d'été à lacets taille élastique ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR         100               0    3.76            54
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
data2.duplicated().sum()
# Out:
# 34

# %%
data2.shape
# Out:
# (1573, 43)

# %% [markdown]
# ## clean data

# %%
data2.drop_duplicates(inplace=  True)

# %%
data2.isnull().sum()
# Out:
# title                              0
# title_orig                         0
# price                              0
# retail_price                       0
# currency_buyer                     0
# units_sold                         0
# uses_ad_boosts                     0
# rating                             0
# rating_count                       0
# rating_five_count                 43
# rating_four_count                 43
# rating_three_count                43
# rating_two_count                  43
# rating_one_count                  43
# badges_count                       0
# badge_local_product                0
# badge_product_quality              0
# badge_fast_shipping                0
# tags                               0
# product_color                     41
# product_variation_size_id         14
# product_variation_inventory        0
# shipping_option_name               0
# shipping_option_price              0
# shipping_is_express                0
# ...

# %%
subData2=data2[data2.iloc[:, 8:15].isnull().any(axis=1)]
subData2.iloc[:,7:15]
# Out:
#       rating  rating_count  rating_five_count  rating_four_count  \
# 74       5.0             0                NaN                NaN
# 112      5.0             0                NaN                NaN
# 126      5.0             0                NaN                NaN
# 189      5.0             0                NaN                NaN
# 216      5.0             0                NaN                NaN
# 248      5.0             0                NaN                NaN
# 309      5.0             0                NaN                NaN
# 346      5.0             0                NaN                NaN
# 348      5.0             0                NaN                NaN
# 375      5.0             0                NaN                NaN
# 438      5.0             0                NaN                NaN
# 481      5.0             0                NaN                NaN
# 487      5.0             0                NaN                NaN
# ...

# %%
data2.fillna({
    'rating_five_count': 0,
    'rating_four_count': 0,
    'rating_three_count': 0,
    'rating_two_count': 0,
    'rating_one_count': 0
}, inplace=True)

# %%
data2.isnull().sum()
# Out:
# title                              0
# title_orig                         0
# price                              0
# retail_price                       0
# currency_buyer                     0
# units_sold                         0
# uses_ad_boosts                     0
# rating                             0
# rating_count                       0
# rating_five_count                  0
# rating_four_count                  0
# rating_three_count                 0
# rating_two_count                   0
# rating_one_count                   0
# badges_count                       0
# badge_local_product                0
# badge_product_quality              0
# badge_fast_shipping                0
# tags                               0
# product_color                     41
# product_variation_size_id         14
# product_variation_inventory        0
# shipping_option_name               0
# shipping_option_price              0
# shipping_is_express                0
# ...

# %%
data2['product_color'].value_counts()
# Out:
# product_color
# black                 298
# white                 246
# yellow                101
# pink                   97
# blue                   96
#                      ...
# Rose red                1
# greysnakeskinprint      1
# denimblue               1
# offwhite                1
# gold                    1
# Name: count, Length: 101, dtype: int64

# %%
import numpy as np
data2.fillna({
    'product_color': pd.Series(np.random.choice(['black', 'white'], size=len(data2.index)))
}, inplace=True)

# %%
data2['product_variation_size_id'].unique()
# Out:
# array(['M', 'XS', 'S', 'Size-XS', 'M.', 'XXS', 'L', 'XXL', nan, 'S.', 's',
#        'choose a size', 'XS.', '32/L', 'Suit-S', 'XXXXXL', 'EU 35', '4',
#        'Size S.', '1m by 3m', '3XL', 'Size S', 'XL', 'Women Size 36',
#        'US 6.5 (EU 37)', 'XXXS', 'SIZE XS', '26(Waist 72cm 28inch)',
#        'Size XXS', '29', '1pc', '100 cm', 'One Size', 'SIZE-4XL', '1',
#        'S/M(child)', '2pcs', 'XXXL', 'S..', '30 cm', '5XL', '33',
#        'Size M', '100 x 100cm(39.3 x 39.3inch)', '100pcs', '2XL', '4XL',
#        'SizeL', 'SIZE XXS', 'XXXXL', 'Base & Top & Matte Top Coat',
#        'size S', '35', '34', 'SIZE-XXS', 'S(bust 88cm)',
#        'S (waist58-62cm)', 'S(Pink & Black)', '20pcs', 'US-S',
#        'Size -XXS', 'X   L', 'White', '25', 'Size-S', 'Round',
#        'Pack of 1', '1 pc.', 'S Diameter 30cm', '6XL',
#        'AU plug Low quality', '5PAIRS', '25-S', 'Size/S', 'S Pink',
#        'Size-5XL', 'daughter 24M', '2', 'Baby Float Boat', '10 ml', '60',
# ...

# %%
data2['product_variation_size_id']=data2['product_variation_size_id'].replace({
    'M.': 'M',
    'XS.': 'XS',
    'Size-XS': 'XS',
    'Size-S': 'S',
    'Size-M': 'M',
    'Size-L': 'L',
    'Size-XL': 'XL',
    'Size-XXL': '2XL',
    'Size-XXXL': '3XL',
    'Size-4XL': '4XL',
    'Size-5XL': '5XL',
    'Size-XXS': 'XS',
    'Size -XXS': 'XS',
    'Size-XXS': 'XS',
    'Size XXS': 'XS',
    'SIZE-XXS': 'XS',
    'SIZE XS': 'XS',
    'XXS': 'XS',
    'XXXS': 'XS',
    'XXXXS': 'XS',
    'S.': 'S',
    'S..': 'S',
    'S': 'S',
    's': 'S',
    'S(bust 88cm)': 'S',
    'S (waist58-62cm)': 'S',
    'S Diameter 30cm': 'S',
    'S(Pink & Black)': 'S',
    'US-S': 'S',
    'Suit-S': 'S',
    'Size-S': 'S',
    'Size/S': 'S',
    'SIZE S': 'S',
    'size S': 'S',
    'Size S': 'S',
    'Size S.': 'S',
    'pants-S': 'S',
    'S Pink': 'S',
    'S/M(child)': 'S',
    'M': 'M',
    'L.': 'L',
    'SizeL': 'L',
    'L': 'L',
    'Size M': 'M',
    'Size L': 'L',
    'Size-L': 'L',
    'X   L': 'XL',
    'Size-5XL': '5XL',
    'XXL': '2XL',
    'Size-XXL': '2',
    '32/L': 'L',
    'XXXXL': '4XL',
    'XXXXXL': '5XL',
    '2XL': '2XL',
    'first  generation': '',
    'choose a size': '',
    'Women Size 36': '',
    'Women Size 37': '',
    'US 6.5 (EU 37)': 'S',
    'US5.5-EU35': 'S',
    'EU 35': 'S',
    'EU39(US8)': 'M',
    'AU plug Low quality': '',
    '1pc': '',
    '2pcs': '',
    'Pack of 1': '',
    'Base & Top & Matte Top Coat': '',
    '1 pc.': '',
    'Base Coat': '',
    'Round': '',
    'Baby Float Boat': '',
    'Floating Chair for Kid': '',
    '3 layered anklet': '',
    'B': '',
    '1m by 3m': '',
    'H01': '',
    '1': '',
    '2': '',
    '29': '',
    '25': '',
    '5': '',
    '33': '',
    '34': '',
    '35': '',
    '36': '',
    '40 cm': '',
    '100 cm': '',
    '100pcs': '',
    '30 cm': '',
    '10pcs': '',
    '20pcs': '',
    '20PCS-10PAIRS': '',
    '5PAIRS': '',
    '10 ml': '',
    '80 X 200 CM': '',
    '26(Waist 72cm 28inch)': '',
    '1 PC - XL': 'XL',
    '17': '',
    '25-S': 'S',
    'Size4XL': '4XL',
    '04-3XL': '3XL',
    '100 x 100cm(39.3 x 39.3inch)': '',
    '4':'',
    'SIZE-4XL': '4XL',
    'White':'',
    'daughter 24M':'',
    '60':'',
    '4-5 Years':'',
    'Size--S':'S',
   'SIZE XXS': 'XS'



})

# %%
data2['product_variation_size_id'].unique()
# Out:
# array(['M', 'XS', 'S', 'L', '2XL', nan, '', '5XL', '3XL', 'XL',
#        'One Size', '4XL', 'XXXL', '6XL'], dtype=object)

# %%
data2['product_variation_size_id'].value_counts()
# Out:
# product_variation_size_id
# S           684
# XS          464
# M           205
#              57
# L            55
# 2XL          19
# XL           19
# 4XL          10
# 5XL           5
# 3XL           3
# One Size      2
# XXXL          1
# 6XL           1
# Name: count, dtype: int64

# %%
# First, fill NaN values with random choices
data2.fillna({
    'product_variation_size_id': pd.Series(np.random.choice(['S', 'XS'], size=len(data2.index)))
}, inplace=True)

# Then, replace empty strings with random choices
data2['product_variation_size_id'] = data2['product_variation_size_id'].apply(
    lambda x: np.random.choice(['S', 'XS']) if x == '' else x
)

# %%
data2['has_urgency_banner'].value_counts()
# Out:
# has_urgency_banner
# 1.0    468
# Name: count, dtype: int64

# %%
data2.fillna({'has_urgency_banner':0},inplace=True)

# %%
data2['urgency_text'].value_counts()
# Out:
# urgency_text
# Quantité limitée !                  467
# Réduction sur les achats en gros      1
# Name: count, dtype: int64

# %%
data2['urgency_text']=data2['urgency_text'].replace({
    'Quantité limitée !': 'Limited quantity!',
   'Réduction sur les achats en gro':'Discount on bulk purchases'

})

# %%
data2.fillna({'urgency_text':'no urgency text'},inplace=True)

# %%
data2['origin_country'].value_counts()
# Out:
# origin_country
# CN    1484
# US      31
# VE       4
# SG       2
# AT       1
# GB       1
# Name: count, dtype: int64

# %%
data2.fillna({'origin_country':'CN'},inplace=True)

# %% [markdown]
# remove unnecessary columns

# %%
data2.drop(['merchant_profile_picture', 'merchant_has_profile_picture', 'merchant_title','merchant_info_subtitle','crawl_month','theme','product_picture','product_url','title'], axis=1, inplace=True)

# %%
data2.isnull().sum()
# Out:
# title_orig                     0
# price                          0
# retail_price                   0
# currency_buyer                 0
# units_sold                     0
# uses_ad_boosts                 0
# rating                         0
# rating_count                   0
# rating_five_count              0
# rating_four_count              0
# rating_three_count             0
# rating_two_count               0
# rating_one_count               0
# badges_count                   0
# badge_local_product            0
# badge_product_quality          0
# badge_fast_shipping            0
# tags                           0
# product_color                  0
# product_variation_size_id      0
# product_variation_inventory    0
# shipping_option_name           0
# shipping_option_price          0
# shipping_is_express            0
# countries_shipped_to           0
# inventory_total                0
# has_urgency_banner             0
# urgency_text                   0
# ...

# %%
data2.fillna({'merchant_name':data2['merchant_name'].mode},inplace=True)

# %%
data2.isnull().sum()
# Out:
# title_orig                     0
# price                          0
# retail_price                   0
# currency_buyer                 0
# units_sold                     0
# uses_ad_boosts                 0
# rating                         0
# rating_count                   0
# rating_five_count              0
# rating_four_count              0
# rating_three_count             0
# rating_two_count               0
# rating_one_count               0
# badges_count                   0
# badge_local_product            0
# badge_product_quality          0
# badge_fast_shipping            0
# tags                           0
# product_color                  0
# product_variation_size_id      0
# product_variation_inventory    0
# shipping_option_name           0
# shipping_option_price          0
# shipping_is_express            0
# countries_shipped_to           0
# inventory_total                0
# has_urgency_banner             0
# urgency_text                   0
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1539 entries, 0 to 1572
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   title_orig                   1539 non-null   object
#  1   price                        1539 non-null   float64
#  2   retail_price                 1539 non-null   int64
#  3   currency_buyer               1539 non-null   object
#  4   units_sold                   1539 non-null   int64
#  5   uses_ad_boosts               1539 non-null   int64
#  6   rating                       1539 non-null   float64
#  7   rating_count                 1539 non-null   int64
#  8   rating_five_count            1539 non-null   float64
#  9   rating_four_count            1539 non-null   float64
#  10  rating_three_count           1539 non-null   float64
#  11  rating_two_count             1539 non-null   float64
#  12  rating_one_count             1539 non-null   float64
# ...

# %%
data2.head()
# Out:
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR         100               0    3.76            54
# 1            EUR       20000               1    3.45          6135
# 2            EUR         100               0    3.57            14
# 3            EUR        5000               1    4.03           579
# 4            EUR         100               1    3.10            20
#
#    rating_five_count  rating_four_count  ...  countries_shipped_to  \
# ...

# %%
data2.to_csv('cleaned_summer-products-with-rating-and-performance_2020-08.csv', index=False)

# %% [markdown]
# # 3rd

# %%
import pandas as pd
df=pd.read_csv('/content/unique-categories.csv')
df.head()
# Out:
#                 tag
# 0  #fashion #shorts
# 1  #fashion #tshirt
# 2        #Sport Bra
# 3   #Summer Clothes
# 4        #top #crop

# %%
df['tag'].value_counts()
# Out:
# tag
# #fashion #shorts     1
# sheerlacebra         1
# sexydressforwomen    1
# sexyoutfit           1
# sexypleated          1
#                     ..
# gymstighttshirt      1
# gymwear              1
# gypsy                1
# gypsypant            1
# 漁師の帽子                1
# Name: count, Length: 2620, dtype: int64

# %% [markdown]
# # 4th

# %%
data=pd.read_csv('/content/unique-categories.sorted-by-count.csv')
data.head()
# Out:
#    count          keyword
# 0   1321           Summer
# 1   1315  Women's Fashion
# 2   1082          Fashion
# 3    961            Women
# 4    905           Casual

# %%
data.isnull().sum()
# Out:
# count      0
# keyword    0
# dtype: int64

# %%
data['keyword'].unique()
# Out:
# array(['Summer', "Women's Fashion", 'Fashion', ..., '2,Piece Swimsuit',
#        '#fashion #shorts', '#Summer Clothes'], dtype=object)
